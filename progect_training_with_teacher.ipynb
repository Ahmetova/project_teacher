# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span></li><li><span><a href="#Исследование-задачи" data-toc-modified-id="Исследование-задачи-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Исследование задачи</a></span><ul class="toc-item"><li><span><a href="#Подготовка-данных-для-выборок" data-toc-modified-id="Подготовка-данных-для-выборок-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Подготовка данных для выборок</a></span></li><li><span><a href="#Проверка-на-баланс/дисбаланс-классов" data-toc-modified-id="Проверка-на-баланс/дисбаланс-классов-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Проверка на баланс/дисбаланс классов</a></span></li><li><span><a href="#Обучение-моделей-без-учета-дисбаланса" data-toc-modified-id="Обучение-моделей-без-учета-дисбаланса-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Обучение моделей без учета дисбаланса</a></span><ul class="toc-item"><li><span><a href="#Модель-решающего-дерева" data-toc-modified-id="Модель-решающего-дерева-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Модель решающего дерева</a></span></li><li><span><a href="#Модель-случайного-леса" data-toc-modified-id="Модель-случайного-леса-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Модель случайного леса</a></span></li><li><span><a href="#Модель-логистической-регрессии" data-toc-modified-id="Модель-логистической-регрессии-2.3.3"><span class="toc-item-num">2.3.3&nbsp;&nbsp;</span>Модель логистической регрессии</a></span></li><li><span><a href="#Сравнение-моделей" data-toc-modified-id="Сравнение-моделей-2.3.4"><span class="toc-item-num">2.3.4&nbsp;&nbsp;</span>Сравнение моделей</a></span></li></ul></li></ul></li><li><span><a href="#Борьба-с-дисбалансом" data-toc-modified-id="Борьба-с-дисбалансом-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Борьба с дисбалансом</a></span><ul class="toc-item"><li><span><a href="#Взвешивание-классов" data-toc-modified-id="Взвешивание-классов-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Взвешивание классов</a></span><ul class="toc-item"><li><span><a href="#Модель-решающего-дерева" data-toc-modified-id="Модель-решающего-дерева-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Модель решающего дерева</a></span></li><li><span><a href="#Модель-случайного-леса" data-toc-modified-id="Модель-случайного-леса-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>Модель случайного леса</a></span></li><li><span><a href="#Модель-логистической-регрессии" data-toc-modified-id="Модель-логистической-регрессии-3.1.3"><span class="toc-item-num">3.1.3&nbsp;&nbsp;</span>Модель логистической регрессии</a></span></li><li><span><a href="#Сравнение-моделей" data-toc-modified-id="Сравнение-моделей-3.1.4"><span class="toc-item-num">3.1.4&nbsp;&nbsp;</span>Сравнение моделей</a></span></li></ul></li><li><span><a href="#Увеличение-выборки" data-toc-modified-id="Увеличение-выборки-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Увеличение выборки</a></span><ul class="toc-item"><li><span><a href="#Модель-решающего-дерева" data-toc-modified-id="Модель-решающего-дерева-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Модель решающего дерева</a></span></li><li><span><a href="#Модель-случайного-леса" data-toc-modified-id="Модель-случайного-леса-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Модель случайного леса</a></span></li><li><span><a href="#Модель-логистической-регрессии" data-toc-modified-id="Модель-логистической-регрессии-3.2.3"><span class="toc-item-num">3.2.3&nbsp;&nbsp;</span>Модель логистической регрессии</a></span></li><li><span><a href="#Сравнение-моделей" data-toc-modified-id="Сравнение-моделей-3.2.4"><span class="toc-item-num">3.2.4&nbsp;&nbsp;</span>Сравнение моделей</a></span></li></ul></li><li><span><a href="#Уменьшение-выборки" data-toc-modified-id="Уменьшение-выборки-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Уменьшение выборки</a></span><ul class="toc-item"><li><span><a href="#Модель-решающего-дерева" data-toc-modified-id="Модель-решающего-дерева-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Модель решающего дерева</a></span></li><li><span><a href="#Модель-случайного-леса" data-toc-modified-id="Модель-случайного-леса-3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>Модель случайного леса</a></span></li><li><span><a href="#Модель-логистической-регрессии" data-toc-modified-id="Модель-логистической-регрессии-3.3.3"><span class="toc-item-num">3.3.3&nbsp;&nbsp;</span>Модель логистической регрессии</a></span></li><li><span><a href="#Сравнение-моделей" data-toc-modified-id="Сравнение-моделей-3.3.4"><span class="toc-item-num">3.3.4&nbsp;&nbsp;</span>Сравнение моделей</a></span></li></ul></li><li><span><a href="#Изменение-порога" data-toc-modified-id="Изменение-порога-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Изменение порога</a></span><ul class="toc-item"><li><span><a href="#Модель-решающего-дерева" data-toc-modified-id="Модель-решающего-дерева-3.4.1"><span class="toc-item-num">3.4.1&nbsp;&nbsp;</span>Модель решающего дерева</a></span></li><li><span><a href="#Модель-случайного-леса" data-toc-modified-id="Модель-случайного-леса-3.4.2"><span class="toc-item-num">3.4.2&nbsp;&nbsp;</span>Модель случайного леса</a></span></li><li><span><a href="#Модель-логистической-регрессии" data-toc-modified-id="Модель-логистической-регрессии-3.4.3"><span class="toc-item-num">3.4.3&nbsp;&nbsp;</span>Модель логистической регрессии</a></span></li><li><span><a href="#Сравнение-моделей" data-toc-modified-id="Сравнение-моделей-3.4.4"><span class="toc-item-num">3.4.4&nbsp;&nbsp;</span>Сравнение моделей</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Тестирование-модели" data-toc-modified-id="Тестирование-модели-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Тестирование модели</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Отток клиентов

# %% [markdown]
# Из «Бета-Банка» стали уходить клиенты. Каждый месяц. Немного, но заметно. Банковские маркетологи посчитали: сохранять текущих клиентов дешевле, чем привлекать новых.
#
# Нужно спрогнозировать, уйдёт клиент из банка в ближайшее время или нет. Вам предоставлены исторические данные о поведении клиентов и расторжении договоров с банком.
#
# Постройте модель с предельно большим значением *F1*-меры. Чтобы сдать проект успешно, нужно довести метрику до 0.59. Проверьте *F1*-меру на тестовой выборке самостоятельно.
#
# Дополнительно измеряйте *AUC-ROC*, сравнивайте её значение с *F1*-мерой.
#
# Источник данных: [https://www.kaggle.com/barelydedicated/bank-customer-churn-modeling](https://www.kaggle.com/barelydedicated/bank-customer-churn-modeling)

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# **Загрузим необходиые нам библиотеки.**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats as st

# Для задач классификации
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

from sklearn.model_selection import train_test_split

# Масштабирование признаков
from sklearn.preprocessing import StandardScaler 

# Метрики
from sklearn.metrics import (
    accuracy_score, 
    roc_auc_score, 
    f1_score,
    recall_score,
    precision_score
)

# для измерения времени работы программы
import time

from sklearn.utils import shuffle

# ROC-кривая
from sklearn.metrics import roc_curve 

# для проверки адекватности модели
from sklearn.dummy import DummyClassifier

# для обработки названия столбцов
import re

# %% [markdown]
# Сохраним в переменной `data` данные о клиентах банка. Выведем первые и последние пять строк получившегося датафрейма.

# %%
data = pd.read_csv('/datasets/Churn.csv')
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0     2.0       0.00              1          1               1
# 1     1.0   83807.86              1          0               1
# 2     8.0  159660.80              3          1               0
# 3     1.0       0.00              2          0               0
# 4     2.0  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
data.tail()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995     5.0       0.00              2          1               0
# 9996    10.0   57369.61              1          1               1
# 9997     7.0       0.00              1          0               1
# 9998     3.0   75075.31              2          1               0
# 9999     NaN  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# ...

# %% [markdown]
# Выведем основную информацию о датафрейме с помощью методов `info()` и `describe()`.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           9091 non-null   float64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(3), int64(8), object(3)
# memory usage: 1.1+ MB

# %%
data.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age       Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  9091.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800     4.997690
# std     2886.89568  7.193619e+04     96.653299     10.487806     2.894723
# min        1.00000  1.556570e+07    350.000000     18.000000     0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000     2.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000     5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000     7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000    10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %% [markdown]
# Рассматривая полученную информацию, сразу можно заметить, что только в одном столбце, `Tenure`, присутствуют пропуски в значениях.
#
# Можно предположить, что пропуски связаны либо с человеческим фактором, либо произошел сбой пи передаче данных (но в других столбцах нет пропусков, поэтому вряд ли). Заменим пропуски медианным значением.

# %%
data['Tenure'] = data['Tenure'].fillna(data['Tenure'].mean())

# %% [markdown]
# Проверим отсутствие пропусков.

# %%
data.isna().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# Приведем названия столбцов к читаемому виду (знаю, что можно было бы этого не делать, но мне так проще работать). Заменим:
#
# - `RowNumber` на `row_number`;
# - `CustomerId` на `customer_id`;
# - `Surname` на `surname`;
# - `CreditScore` на `credit_score`;
# - `Geography` на `geography`;
# - `Gender` на `gender`;
# - `Age` на `age`;
# - `Tenure` на `tenure`;
# - `Balance` на `balance`;
# - `NumOfProducts` на `num_of_products`;
# - `HasCrCard` на `has_cr_card`;
# - `IsActiveMember` на `is_active_member`;
# - `EstimatedSalary` на `estimated_salary`;
# - `Exited` на `exited`.

# %%
data.columns = [re.sub(r'(?<!^)(?=[A-Z])', '_', i).lower() for i in data.columns]
data.columns
# Out:
# Index(['row_number', 'customer_id', 'surname', 'credit_score', 'geography',
#        'gender', 'age', 'tenure', 'balance', 'num_of_products', 'has_cr_card',
#        'is_active_member', 'estimated_salary', 'exited'],
#       dtype='object')

# %% [markdown]
# Проверим таблицу на наличие дубликатов (исключая столбец `row_number`).

# %%
len(data[data.drop('row_number', axis=1).duplicated()])
# Out:
# 0

# %% [markdown]
# Дубликаты отсутствуют. Также проверим столбец `geography` со странами проживания на неявные дубликаты (разное написание одних и тех же стран, прописные и строчные буквы и т.д.). Рассмотрим все уникальные значения.

# %%
data['geography'].unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %% [markdown]
# Здесь все в порядке.

# %% [markdown]
# Также отдельно рассмотрим столбец `exited` (целевой признак). Построим круговую диагармму.

# %%
data['exited'].value_counts()
# Out:
# 0    7963
# 1    2037
# Name: exited, dtype: int64

# %%
data['exited'].value_counts().plot(kind='pie', y=data['exited'].value_counts(), autopct='%1.0f%%', figsize=(7,7), title='Распределение факта уходов клиентов')

plt.ylabel('факт ухода клиента')
plt.show()

# %% [markdown]
# Видно, что данных о клиентах, которые не ушли из банка, больше, чем о клиентах, покинувших данный банк.

# %% [markdown]
# Изучим корреляции в данных. Так мы сможем оценить взаимосвязи в данных и влияние параметров на целевой признак. Из признаков убираем те, что не несут влияния на целевой признак (например, уникальный идентификатор клиента или индекс строки).

# %%
sns.pairplot(data.drop(['row_number', 'customer_id', 'surname'], axis=1), hue="exited")
plt.show()

# %% [markdown]
# Рассмотривая полученные графики, можно заметить отсутствие мультиколлениарности (при ее наличие удаление одного из признаков хорошо бы сказалось на эффективности модели). Средний возраст клиентов, пожелавших уйти из банка около 45 лет, у оставшихся в банке - около 30. Можно заметить, что большим количеством продуктов банка использовали клиенты, которые по итогу ушли из банка. Баланс на счетах клиентов распределен около двух пиков: около 0 (на счете нет средств) и около 115.000.

# %% [markdown]
# **Вывод**
#
# При рассмотрении полученных данных, были сделаны следующие выводы:
#
# - в данных отсутствовали значения только в столбце `Tenure`. Была произведена замена пропусков на минимальное значение 0;
# - в данных отсутствовали дубликаты;
# - построены графики и изучены корреляции в данных. Мультиколлениарность не обнаружена.

# %% [markdown]
# ## Исследование задачи

# %% [markdown]
# ### Подготовка данных для выборок

# %% [markdown]
# Для начала необходимо создать две таблицы данных: таблица с признаками - `features`, таблица с целевым признаком - `target`.
#
# Но перед этим подробнее разберемся с признаками.
#
# **1.** Очевидно, что столбцы `row_number`, `customer_id` и `surname` не несут никакого информативного характера для определения, останется ли клиент в банке или уйдет. Скорее информация в них только еще больше запутает модель. Поэтому в таблицу с признаками данные столбцы не войдут.
#
# **2.** В данных имеются как количественные признаки, так и категориальные. Следовательно, необходимо преобразовать категориальные признаки в численные. Используем технику прямого кодирования - OHE, с обходом дамми-ловушек.

# %%
data_ohe = pd.get_dummies(data, drop_first=True, columns=['gender', 'geography'])
data_ohe.head()
# Out:
#    row_number  customer_id   surname  credit_score  age  tenure    balance  \
# 0           1     15634602  Hargrave           619   42     2.0       0.00
# 1           2     15647311      Hill           608   41     1.0   83807.86
# 2           3     15619304      Onio           502   42     8.0  159660.80
# 3           4     15701354      Boni           699   39     1.0       0.00
# 4           5     15737888  Mitchell           850   43     2.0  125510.82
#
#    num_of_products  has_cr_card  is_active_member  estimated_salary  exited  \
# 0                1            1                 1         101348.88       1
# 1                1            0                 1         112542.58       0
# 2                3            1                 0         113931.57       1
# 3                2            0                 0          93826.63       0
# 4                1            1                 1          79084.10       0
#
#    gender_Male  geography_Germany  geography_Spain
# ...

# %% [markdown]
# **3.** Создадим две таблицы данных: таблица с признаками - `features`, таблица с целевым признаком - `target`.

# %%
features = data_ohe.drop(['exited', 'row_number', 'customer_id', 'surname'], axis=1)
target = data['exited']

display('features:', features.head())
display('target:', target.head())

pd.options.mode.chained_assignment = None
# Out:
# 'features:'
#    credit_score  age  tenure    balance  num_of_products  has_cr_card  \
# 0           619   42     2.0       0.00                1            1
# 1           608   41     1.0   83807.86                1            0
# 2           502   42     8.0  159660.80                3            1
# 3           699   39     1.0       0.00                2            0
# 4           850   43     2.0  125510.82                1            1
#
#    is_active_member  estimated_salary  gender_Male  geography_Germany  \
# 0                 1         101348.88            0                  0
# 1                 1         112542.58            0                  0
# 2                 0         113931.57            0                  0
# 3                 0          93826.63            0                  0
# 4                 1          79084.10            0                  0
#
#    geography_Spain
# 0                0
# 1                1
# 2                0
# 3                0
# ...

# %% [markdown]
# Разобьем наши данные на три выборки: обучающую, валидационную и тестовую, в соотношении 3:1:1.
#
# Для этого сначала разобъем данные на обучающую и тестовую выборки.

# %%
features_train, features_test, target_train, target_test = train_test_split(
    features, target, test_size=0.4, random_state=12345)

# %% [markdown]
# Теперь разобъем тестовые данные на тестовую выборку и валидационную (делим пополам).

# %%
features_test, features_valid, target_test, target_valid = train_test_split(
    features_test, target_test, test_size=0.5, random_state=12345)

print('Тренировочная:', features_train.shape)
print('Валидационная:', features_valid.shape)
print('Тестовая:', features_test.shape)
# Out:
# Тренировочная: (6000, 11)
# Валидационная: (2000, 11)
# Тестовая: (2000, 11)

# %% [markdown]
# Таким образом, разбили имеющиеся данные на три выборки в соотношении 3:1:1.

# %% [markdown]
# **4.** Для того, что избежать ситуации, когда при обучении модели один какой-либо признак из-за наличия больших значений был засчитан как более значимый, в численных признаках в столбцах `credit_score`, `age`, `tenure`, `balance`, `num_of_products` и `estimated_salary` необходимо провести масштабирование. Для этого воспользуемся методом стандаризации данных.

# %%
scaler = StandardScaler()

numeric = ['credit_score', 'age', 'tenure', 'balance', 'num_of_products', 'estimated_salary']

scaler.fit(features_train[numeric]) 

features_train[numeric] = scaler.transform(features_train[numeric])
features_valid[numeric] = scaler.transform(features_valid[numeric])
features_test[numeric] = scaler.transform(features_test[numeric])

display('features_train:', features_train.head())
display('features_valid:', features_valid.head())
display('features_test:', features_test.head())

# %% [markdown]
# ### Проверка на баланс/дисбаланс классов

# %% [markdown]
# В первом пункте нашей работы (1.Подготовка данных) мы уже нарисовали круговую диагарамму распределения классов для целевого признака. Снова ее здесь приведем.

# %%
data['exited'].value_counts()
# Out:
# 0    7963
# 1    2037
# Name: exited, dtype: int64

# %%
data['exited'].value_counts().plot(kind='pie', y=data['exited'].value_counts(), autopct='%1.0f%%', figsize=(7,7), title='Распределение факта уходов клиентов')

plt.ylabel('факт ухода клиента')
plt.show()

# %% [markdown]
# Как видно из количества значений и круговой диаграммы классы несбалансированны. Количество оставшихся в банке клиентов превышает ушедших из банка в почти 4 раза.

# %% [markdown]
# ### Обучение моделей без учета дисбаланса

# %% [markdown]
# Посмотрим, как будут вести себя модели, если не сбалансировать классы для целевого признака.
#
# Рассмотрим три модели:
# - модель решающего дерева;
# - модель случайного леса;
# - модель логистической регрессии.

# %% [markdown]
# #### Модель решающего дерева
#
# Будем подбирать гиперпараметр `max_depth` в цикле.

# %%
best_model_Tree = None
best_f1_Tree = 0
best_depth = 0

start_time = time.perf_counter()

for depth in range(1, 100):
    model = DecisionTreeClassifier(random_state=12345, max_depth=depth) # модель
    model.fit(features_train, target_train) # обучение модели
    predictions_valid_Tree = model.predict(features_valid) # предсказания 
    f1 = f1_score(target_valid, predictions_valid_Tree)
    if best_f1_Tree < f1:
        best_model_Tree = model
        best_f1_Tree = f1
        best_depth = depth

end_time = time.perf_counter()
elapsed_time_Tree = end_time - start_time

print('Гиперпараметры:', end='\n')
print("best_depth =", best_depth)
print()
print("best_f1_Tree =", best_f1_Tree) 
print('Время работы программы =', elapsed_time_Tree, 'сек')
# Out:
# Гиперпараметры:
# best_depth = 6
#
# best_f1_Tree = 0.5359877488514548
# Время работы программы = 2.9970329608768225 сек

# %% [markdown]
# Лучшее значение `f1_score` получаем при глубине дерева равной 6.
#
# #### Модель случайного леса
#
# Подберем гиперпараметры `max_depth` и `n_estimators` в цикле.

# %%
best_model_Forest = None
best_f1_Forest = 0
best_est = 0
best_depth = 0

start_time = time.perf_counter()

for est in range(10, 50):
    for depth in range (1, 25):
        model = RandomForestClassifier(random_state=12345, n_estimators=est, max_depth=depth) # модель
        model.fit(features_train, target_train) # обучение модель 
        predictions_valid_Forest = model.predict(features_valid) # предсказания модели 
        f1 = f1_score(target_valid, predictions_valid_Forest)
        if best_f1_Forest < f1:
            best_model_Forest = model
            best_f1_Forest = f1
            best_est = est
            best_depth = depth
            
end_time = time.perf_counter()
elapsed_time_Forest = end_time - start_time

print('Гиперпараметры:', end='\n')
print("best_depth =", best_depth, end='\n')
print("best_n_estimators =", best_est, end='\n')
print()
print("best_f1_Forest =", best_f1_Forest) 
print('Время работы программы =', elapsed_time_Forest, 'сек')
# Out:
# Гиперпараметры:
# best_depth = 20
# best_n_estimators = 31
#
# best_f1_Forest = 0.5582089552238806
# Время работы программы = 167.39568981528282 сек

# %% [markdown]
# Лучшее значение `f1_score` получаем при количестве деревьев равное 31 и глубине каждого дерева равного 20.
#
# #### Модель логистической регрессии

# %%
start_time = time.perf_counter()

model_Log = LogisticRegression(random_state=12345, solver='lbfgs', max_iter=1000)
model_Log.fit(features_train, target_train)
prediction_valid_Log = model_Log.predict(features_valid)
f1_Log = f1_score(target_valid, prediction_valid_Log)

end_time = time.perf_counter()
elapsed_time_Log = end_time - start_time

print('f1_score_Log =', f1_Log)
print('Время работы программы =', elapsed_time_Log, 'сек')
# Out:
# f1_score_Log = 0.13737373737373737
# Время работы программы = 0.44635467045009136 сек

# %% [markdown]
# #### Сравнение моделей
#
# Теперь рассмотрим дополнительно метрики полноты, точности и accuracy. Для этого сначала обучим модели на основе подобранных гиперпараметров.

# %%
# модель решающего дерева
model_tree = DecisionTreeClassifier(random_state=12345, max_depth=6) # модель
model_tree.fit(features_train, target_train) # обучение модели
predictions_valid_tree = model.predict(features_valid) # предсказания

# модель случайного леса
model_forest = RandomForestClassifier(random_state=12345, n_estimators=31, max_depth=20) # модель
model_forest.fit(features_train, target_train) # обучение модель 
predictions_valid_forest = model.predict(features_valid) # предсказания модели

# %% [markdown]
# Теперь рассчитаем все метрики. Для этого напишем функцию `metrics`.

# %%
def metrics(target, predictions):
    res = {}
    for prediction in predictions:
        res['recall'] = res.get('recall', [])+[recall_score(target, prediction)]
        res['precision'] = res.get('precision', [])+[precision_score(target, prediction)]
        res['accuracy'] = res.get('accuracy', [])+[accuracy_score(target, prediction)]
    return res

# %% [markdown]
# Теперь выведем все найденные метрики в одну общую таблицу.

# %%
dict1 = {'f1': [best_f1_Tree, best_f1_Forest, f1_Log], 'time': [elapsed_time_Tree, elapsed_time_Forest, elapsed_time_Log]}
dict2 = metrics(target_valid, [predictions_valid_tree, predictions_valid_forest, prediction_valid_Log])
dict1.update(dict2)

data_metrics = pd.DataFrame(data=dict1, index=['Решающее дерево', 'Случайный лес', 'Логистическая регрессия'])
data_metrics
# Out:
#                                f1        time    recall  precision  accuracy
# Решающее дерево          0.535988    2.997033  0.413712   0.729167    0.8435
# Случайный лес            0.558209  167.395690  0.413712   0.729167    0.8435
# Логистическая регрессия  0.137374    0.446355  0.080378   0.472222    0.7865

# %% [markdown]
# **Вывод**
#
# Рассмативая полученную таблицу, можно сделать вывод о том, что наилучший результат показывают модели решающего дерева и случайного леса.
#
# Можн заметить, что для модели логистической регрессии значение accuracy и точности лучше, но на данный момент более важной метрикой является F1-мера, поэтому мы не выбираем данную модель.

# %% [markdown]
# ## Борьба с дисбалансом

# %% [markdown]
# Для борьбы с дисбалансом существуют несколько методов. Рассмотрим следующие три:
# - взвешивание классов;
# - увеличение выборки;
# - уменьшение выборки;
# - изменение порога классификации.
#
# Рассмотрим те же модели, что и в пункте 2.3 и аналогично подберем гиперпараметры.
#
# ### Взвешивание классов
#
# #### Модель решающего дерева
#
# Будем подбирать гиперпараметр `max_depth` в цикле.

# %%
best_model_Tree = None
best_f1_Tree = 0
best_depth = 0

start_time = time.perf_counter()

for depth in range(1, 100):
    model = DecisionTreeClassifier(random_state=12345, max_depth=depth, class_weight='balanced') # модель
    model.fit(features_train, target_train) # обучение модели
    predictions_valid_Tree = model.predict(features_valid) # предсказания 
    f1 = f1_score(target_valid, predictions_valid_Tree)
    if best_f1_Tree < f1:
        best_model_Tree = model
        best_f1_Tree = f1
        best_depth = depth

end_time = time.perf_counter()
elapsed_time_Tree = end_time - start_time

print('Гиперпараметры:', end='\n')
print("best_depth =", best_depth)
print()
print("best_f1_Tree =", best_f1_Tree) 
print('Время работы программы =', elapsed_time_Tree, 'сек')
# Out:
# Гиперпараметры:
# best_depth = 5
#
# best_f1_Tree = 0.5809128630705395
# Время работы программы = 2.9405921343714 сек

# %% [markdown]
# Лучшее значение `accuracy` получаем при глубине дерева равной 5.
#
# #### Модель случайного леса
#
# Подберем гиперпараметры `max_depth` и `n_estimators` в цикле.

# %%
best_model_Forest = None
best_f1_Forest = 0
best_est = 0
best_depth = 0

start_time = time.perf_counter()

for est in range(10, 50):
    for depth in range (1, 25):
        model = RandomForestClassifier(random_state=12345, n_estimators=est, max_depth=depth, class_weight='balanced') # модель
        model.fit(features_train, target_train) # обучение модель 
        predictions_valid_Forest = model.predict(features_valid) # предсказания модели 
        f1 = f1_score(target_valid, predictions_valid_Forest)
        if best_f1_Forest < f1:
            best_model_Forest = model
            best_f1_Forest = f1
            best_est = est
            best_depth = depth
            
end_time = time.perf_counter()
elapsed_time_Forest = end_time - start_time

print('Гиперпараметры:', end='\n')
print("best_depth =", best_depth, end='\n')
print("best_n_estimators =", best_est, end='\n')
print()
print("best_f1_Forest =", best_f1_Forest) 
print('Время работы программы =', elapsed_time_Forest, 'сек')
# Out:
# Гиперпараметры:
# best_depth = 8
# best_n_estimators = 16
#
# best_f1_Forest = 0.6224598930481284
# Время работы программы = 166.053715698421 сек

# %% [markdown]
# Лучшее значение `f1_score` получаем при количестве деревьев равное 16 и глубине каждого дерева равного 8.
#
# #### Модель логистической регрессии

# %%
start_time = time.perf_counter()

model_Log = LogisticRegression(random_state=12345, solver='lbfgs', max_iter=1000, class_weight='balanced')
model_Log.fit(features_train, target_train)
prediction_valid_Log = model_Log.predict(features_valid)
f1_Log = f1_score(target_valid, prediction_valid_Log)

end_time = time.perf_counter()
elapsed_time_Log = end_time - start_time

print('f1_Log =', f1_Log)
print('Время работы программы =', elapsed_time_Log, 'сек')
# Out:
# f1_Log = 0.4294770206022187
# Время работы программы = 0.2827514074742794 сек

# %% [markdown]
# #### Сравнение моделей
#
# Теперь рассмотрим дополнительно метрики полноты, точности и accuracy. Для этого сначала обучим модели на основе подобранных гиперпараметров.

# %%
# модель решающего дерева
model_tree = DecisionTreeClassifier(random_state=12345, max_depth=5, class_weight='balanced') # модель
model_tree.fit(features_train, target_train) # обучение модели
predictions_valid_tree = model.predict(features_valid) # предсказания

# модель случайного леса
model_forest = RandomForestClassifier(random_state=12345, n_estimators=16, max_depth=8, class_weight='balanced') # модель
model_forest.fit(features_train, target_train) # обучение модель 
predictions_valid_forest = model.predict(features_valid) # предсказания модели

# %% [markdown]
# Теперь выведем все найденные метрики в одну общую таблицу и сравним с таблицей значений до взвешивания классов.

# %%
def bold_text(text): # функция для печати жирным шрифтом
    bold_start = '\033[1m'
    bold_end = '\033[0m'
    return bold_start + text + bold_end

# %%
dict1 = {'f1': [best_f1_Tree, best_f1_Forest, f1_Log], 'time': [elapsed_time_Tree, elapsed_time_Forest, elapsed_time_Log]}
dict2 = metrics(target_valid, [predictions_valid_tree, predictions_valid_forest, prediction_valid_Log])
dict1.update(dict2)

print(bold_text('До борьбы с дисбалансом:'))
display(data_metrics)
print()

print(bold_text('После борьбы с дисбалансом с помощью взвешивания классов:'))
data_metrics_balanced = pd.DataFrame(data=dict1, index=['Решающее дерево', 'Случайный лес', 'Логистическая регрессия'])
display(data_metrics_balanced)
# Out:
# До борьбы с дисбалансом:
#                                f1        time    recall  precision  accuracy
# Решающее дерево          0.535988    2.997033  0.413712   0.729167    0.8435
# Случайный лес            0.558209  167.395690  0.413712   0.729167    0.8435
# Логистическая регрессия  0.137374    0.446355  0.080378   0.472222    0.7865
# После борьбы с дисбалансом с помощью взвешивания классов:
#                                f1        time    recall  precision  accuracy
# Решающее дерево          0.580913    2.940592  0.387707   0.752294    0.8435
# Случайный лес            0.622460  166.053716  0.387707   0.752294    0.8435
# Логистическая регрессия  0.429477    0.282751  0.640662   0.323004    0.6400

# %% [markdown]
# **Вывод**
#
# Рассматривая полученную таблицу, можно заметить следующее:
#
# - время обучения модели (с учетом подбора параметров) увеличилось для всех моделей, кроме модели решающего дерева;
# - метрика accuracy увеличилась для всех моделей, кроме модели логистической регрессии (для нее уменьшилась);
# - метрика полноты уменьшилась для всех моделей, кроме модели логистической регрессии;
# - метрика точности увеличилась для первых двух моделей, для логистической регрессии уменьшилась;
# - F1-мера увеличилась для всех моделей.
#
# Таким образом, если не учитывать время работы программы, модель случайного леса наиболее благоприятна для использования.

# %% [markdown]
# ### Увеличение выборки
#
# Напишем функцию `upsample` для увеличения выборки.

# %%
def upsample(features, target, repeat):
    features_zeros = features[target == 0]
    features_ones = features[target == 1]
    target_zeros = target[target == 0]
    target_ones = target[target == 1]

    features_upsampled = pd.concat([features_zeros] + [features_ones] * repeat)
    target_upsampled = pd.concat([target_zeros] + [target_ones] * repeat)
    
    features_upsampled, target_upsampled = shuffle(
        features_upsampled, target_upsampled, random_state=12345)
    
    return features_upsampled, target_upsampled

features_upsampled, target_upsampled = upsample(features_train, target_train, 4)

print(features_upsampled.shape)
print(target_upsampled.shape)
# Out:
# (9588, 11)
# (9588,)

# %% [markdown]
# Сбалансировали выборки.
#
# #### Модель решающего дерева
#
# Будем подбирать гиперпараметр `max_depth` в цикле.

# %%
best_model_Tree = None
best_f1_Tree = 0
best_depth = 0

start_time = time.perf_counter()

for depth in range(1, 100):
    model = DecisionTreeClassifier(random_state=12345, max_depth=depth) # модель
    model.fit(features_upsampled, target_upsampled) # обучение модели
    predictions_valid_Tree = model.predict(features_valid) # предсказания 
    f1 = f1_score(target_valid, predictions_valid_Tree)
    if best_f1_Tree < f1:
        best_model_Tree = model
        best_f1_Tree = f1
        best_depth = depth

end_time = time.perf_counter()
elapsed_time_Tree = end_time - start_time

print('Гиперпараметры:', end='\n')
print("best_depth =", best_depth)
print()
print("best_f1_Tree =", best_f1_Tree) 
print('Время работы программы =', elapsed_time_Tree, 'сек')
# Out:
# Гиперпараметры:
# best_depth = 5
#
# best_f1_Tree = 0.5809128630705395
# Время работы программы = 3.4367118794471025 сек

# %% [markdown]
# Лучшее значение `f1` получаем при глубине дерева равной 5.
#
# #### Модель случайного леса
#
# Подберем гиперпараметры `max_depth` и `n_estimators` в цикле.

# %%
best_model_Forest = None
best_f1_Forest = 0
best_est = 0
best_depth = 0

start_time = time.perf_counter()

for est in range(10, 50):
    for depth in range (1, 25):
        model = RandomForestClassifier(random_state=12345, n_estimators=est, max_depth=depth) # модель
        model.fit(features_upsampled, target_upsampled) # обучение модель 
        predictions_valid_Forest = model.predict(features_valid) # предсказания модели 
        f1 = f1_score(target_valid, predictions_valid_Forest)
        if best_f1_Forest < f1:
            best_model_Forest = model
            best_f1_Forest = f1
            best_est = est
            best_depth = depth
            
end_time = time.perf_counter()
elapsed_time_Forest = end_time - start_time

print('Гиперпараметры:', end='\n')
print("best_depth =", best_depth, end='\n')
print("best_n_estimators =", best_est, end='\n')
print()
print("best_f1_Forest =", best_f1_Forest) 
print('Время работы программы =', elapsed_time_Forest, 'сек')
# Out:
# Гиперпараметры:
# best_depth = 10
# best_n_estimators = 28
#
# best_f1_Forest = 0.6227417640807652
# Время работы программы = 223.96018577180803 сек

# %% [markdown]
# Лучшее значение `f1` получаем при количестве деревьев равное 37 и глубине каждого дерева равного 10.
#
# #### Модель логистической регрессии

# %%
start_time = time.perf_counter()

model_Log = LogisticRegression(random_state=12345, solver='lbfgs', max_iter=1000)
model_Log.fit(features_upsampled, target_upsampled)
prediction_valid_Log = model_Log.predict(features_valid)
f1_Log = f1_score(target_valid, prediction_valid_Log)

end_time = time.perf_counter()
elapsed_time_Log = end_time - start_time

print('f1_Log =', f1_Log)
print('Время работы программы =', elapsed_time_Log, 'сек')
# Out:
# f1_Log = 0.43015873015873013
# Время работы программы = 0.6785477828234434 сек

# %% [markdown]
# #### Сравнение моделей
#
# Теперь рассмотрим дополнительно метрики полноты, точности и accuracy. Для этого сначала обучим модели на основе подобранных гиперпараметров.

# %%
# модель решающего дерева
model_tree = DecisionTreeClassifier(random_state=12345, max_depth=5) # модель
model_tree.fit(features_upsampled, target_upsampled) # обучение модели
predictions_valid_tree = model.predict(features_valid) # предсказания

# модель случайного леса
model_forest = RandomForestClassifier(random_state=12345, n_estimators=37, max_depth=10) # модель
model_forest.fit(features_upsampled, target_upsampled) # обучение модель 
predictions_valid_forest = model.predict(features_valid) # предсказания модели

# %% [markdown]
# Теперь выведем все найденные метрики в одну общую таблицу и сравним с таблицей значений до увеличения выборки.

# %%
dict1 = {'f1': [best_f1_Tree, best_f1_Forest, f1_Log], 'time': [elapsed_time_Tree, elapsed_time_Forest, elapsed_time_Log]}
dict2 = metrics(target_valid, [predictions_valid_tree, predictions_valid_forest, prediction_valid_Log])
dict1.update(dict2)

print(bold_text('До борьбы с дисбалансом:'))
display(data_metrics)
print()

print(bold_text('После борьбы с дисбалансом с помощью увеличения выборки:'))
data_metrics_balanced_increase = pd.DataFrame(data=dict1, index=['Решающее дерево', 'Случайный лес', 'Логистическая регрессия'])
display(data_metrics_balanced_increase)
# Out:
# До борьбы с дисбалансом:
#                                f1        time    recall  precision  accuracy
# Решающее дерево          0.535988    2.997033  0.413712   0.729167    0.8435
# Случайный лес            0.558209  167.395690  0.413712   0.729167    0.8435
# Логистическая регрессия  0.137374    0.446355  0.080378   0.472222    0.7865
# После борьбы с дисбалансом с помощью увеличения выборки:
#                                f1        time    recall  precision  accuracy
# Решающее дерево          0.580913    3.436712  0.510638   0.644776     0.837
# Случайный лес            0.622742  223.960186  0.510638   0.644776     0.837
# Логистическая регрессия  0.430159    0.678548  0.640662   0.323775     0.641

# %% [markdown]
# **Вывод**
#
# Рассматривая полученную таблицу, можно заметить следующее:
#
# - время обучения модели (с учетом подбора параметров) увеличилось для всех моделей (логично, выборки увеличились);
# - метрика accuracy уменьшилась для всех моделей, кроме модели логистической регрессии;
# - метрика полноты увеличилась;
# - метрика точности увеличилась для всех моделей, кроме модели логистической регрессии;
# - F1-мера увеличилась для всех моделей.

# %% [markdown]
# ### Уменьшение выборки
#
# Напишем функцию `downsample` для уменьшения выборки.

# %%
def downsample(features, target, fraction):
    features_zeros = features[target == 0]
    features_ones = features[target == 1]
    target_zeros = target[target == 0]
    target_ones = target[target == 1]

    features_downsampled = pd.concat(
        [features_zeros.sample(frac=fraction, random_state=12345)] + [features_ones])
    target_downsampled = pd.concat(
        [target_zeros.sample(frac=fraction, random_state=12345)] + [target_ones])
    
    features_downsampled, target_downsampled = shuffle(
        features_downsampled, target_downsampled, random_state=12345)
    
    return features_downsampled, target_downsampled

features_downsampled, target_downsampled = downsample(features_train, target_train, 0.25)

print(features_downsampled.shape)
print(target_downsampled.shape)
# Out:
# (2397, 11)
# (2397,)

# %% [markdown]
# Сбалансировали выборки.
#
# #### Модель решающего дерева
#
# Будем подбирать гиперпараметр `max_depth` в цикле.

# %%
best_model_Tree = None
best_f1_Tree = 0
best_depth = 0

start_time = time.perf_counter()

for depth in range(1, 100):
    model = DecisionTreeClassifier(random_state=12345, max_depth=depth) # модель
    model.fit(features_downsampled, target_downsampled) # обучение модели
    predictions_valid_Tree = model.predict(features_valid) # предсказания 
    f1 = f1_score(target_valid, predictions_valid_Tree)
    if best_f1_Tree < f1:
        best_model_Tree = model
        best_f1_Tree = f1
        best_depth = depth

end_time = time.perf_counter()
elapsed_time_Tree = end_time - start_time

print('Гиперпараметры:', end='\n')
print("best_depth =", best_depth)
print()
print("best_f1_Tree =", best_f1_Tree) 
print('Время работы программы =', elapsed_time_Tree, 'сек')
# Out:
# Гиперпараметры:
# best_depth = 5
#
# best_f1_Tree = 0.6093264248704664
# Время работы программы = 1.3259513080120087 сек

# %% [markdown]
# Лучшее значение `accuracy` получаем при глубине дерева равной 5.
#
# #### Модель случайного леса
#
# Подберем гиперпараметры `max_depth` и `n_estimators` в цикле.

# %%
best_model_Forest = None
best_f1_Forest = 0
best_est = 0
best_depth = 0

start_time = time.perf_counter()

for est in range(10, 50):
    for depth in range (1, 25):
        model = RandomForestClassifier(random_state=12345, n_estimators=est, max_depth=depth) # модель
        model.fit(features_downsampled, target_downsampled) # обучение модель 
        predictions_valid_Forest = model.predict(features_valid) # предсказания модели 
        f1 = f1_score(target_valid, predictions_valid_Forest)
        if best_f1_Forest < f1:
            best_model_Forest = model
            best_f1_Forest = f1
            best_est = est
            best_depth = depth
            
end_time = time.perf_counter()
elapsed_time_Forest = end_time - start_time

print('Гиперпараметры:', end='\n')
print("best_depth =", best_depth, end='\n')
print("best_n_estimators =", best_est, end='\n')
print()
print("best_f1_Forest =", best_f1_Forest) 
print('Время работы программы =', elapsed_time_Forest, 'сек')
# Out:
# Гиперпараметры:
# best_depth = 10
# best_n_estimators = 35
#
# best_f1_Forest = 0.5924528301886793
# Время работы программы = 91.19726539589465 сек

# %% [markdown]
# Лучшее значение `f1_score` получаем при количестве деревьев равное 16 и глубине каждого дерева равного 10.
#
# #### Модель логистической регрессии

# %%
start_time = time.perf_counter()

model_Log = LogisticRegression(random_state=12345, solver='lbfgs', max_iter=1000)
model_Log.fit(features_downsampled, target_downsampled)
prediction_valid_Log = model_Log.predict(features_valid)
f1_Log = f1_score(target_valid, prediction_valid_Log)

end_time = time.perf_counter()
elapsed_time_Log = end_time - start_time

print('f1_Log =', f1_Log)
print('Время работы программы =', elapsed_time_Log, 'сек')
# Out:
# f1_Log = 0.4255319148936171
# Время работы программы = 0.12211275100708008 сек

# %% [markdown]
# #### Сравнение моделей
#
# Теперь рассмотрим дополнительно метрики полноты, точности и accuracy. Для этого сначала обучим модели на основе подобранных гиперпараметров.

# %%
# модель решающего дерева
model_tree = DecisionTreeClassifier(random_state=12345, max_depth=5) # модель
model_tree.fit(features_downsampled, target_downsampled) # обучение модели
predictions_valid_tree = model.predict(features_valid) # предсказания

# модель случайного леса
model_forest = RandomForestClassifier(random_state=12345, n_estimators=16, max_depth=10) # модель
model_forest.fit(features_downsampled, target_downsampled) # обучение модель 
predictions_valid_forest = model.predict(features_valid) # предсказания модели

# %% [markdown]
# Теперь выведем все найденные метрики в одну общую таблицу и сравним с таблицей значений до уменьшения выборки.

# %%
dict1 = {'f1': [best_f1_Tree, best_f1_Forest, f1_Log], 'time': [elapsed_time_Tree, elapsed_time_Forest, elapsed_time_Log]}
dict2 = metrics(target_valid, [predictions_valid_tree, predictions_valid_forest, prediction_valid_Log])
dict1.update(dict2)

print(bold_text('До борьбы с дисбалансом:'))
display(data_metrics)
print()

print(bold_text('После борьбы с дисбалансом с помощью уменьшения выборки:'))
data_metrics_balanced_decrease = pd.DataFrame(data=dict1, index=['Решающее дерево', 'Случайный лес', 'Логистическая регрессия'])
display(data_metrics_balanced_decrease)
# Out:
# До борьбы с дисбалансом:
#                                f1        time    recall  precision  accuracy
# Решающее дерево          0.535988    2.997033  0.413712   0.729167    0.8435
# Случайный лес            0.558209  167.395690  0.413712   0.729167    0.8435
# Логистическая регрессия  0.137374    0.446355  0.080378   0.472222    0.7865
# После борьбы с дисбалансом с помощью уменьшения выборки:
#                                f1       time    recall  precision  accuracy
# Решающее дерево          0.609326   1.325951  0.732861   0.461997    0.7630
# Случайный лес            0.592453  91.197265  0.732861   0.461997    0.7630
# Логистическая регрессия  0.425532   0.122113  0.638298   0.319149    0.6355

# %% [markdown]
# **Вывод**
#
# Рассматривая полученную таблицу, можно заметить следующее:
#
# - время обучения модели (с учетом подбора параметров) уменьшилось для всех моделей (логично, выборки уменьшились);
# - метрика accuracy уменьшилась для всех моделей;
# - метрика полноты увеличилась;
# - метрика точности уменьшилась для всех моделей;
# - F1-мера увеличилась для всех моделей.

# %% [markdown]
# ### Изменение порога
#
# #### Модель решающего дерева
#
# Возьмем ранее подобранный гиперпараметр `max_depth` равный 5.

# %%
model_tree = DecisionTreeClassifier(random_state=12345, max_depth=5, class_weight='balanced') # модель
model_tree.fit(features_train, target_train) # обучение модели
probabilities_valid_tree = model_tree.predict_proba(features_valid) 
probabilities_one_valid_tree = probabilities_valid_tree[:, 1]

res_tree = []
res_f1 = []

for threshold in np.arange(0, 1, 0.02):
    predicted_valid = probabilities_one_valid_tree > threshold 
    precision = precision_score(target_valid, predicted_valid)
    recall = recall_score(target_valid, predicted_valid)
    f1 = f1_score(target_valid, predicted_valid)
    res_tree.append([threshold, precision, recall, f1])
    res_f1.append(f1)

    #print("Порог = {:.2f} | Точность = {:.3f}, Полнота = {:.3f}, F1 = {:.3f}".format(
        #threshold, precision, recall, f1))

max_index_tree = res_f1.index(max(res_f1))
    
print('Лучший результат:')
print("Порог = {:.2f} | Точность = {:.3f}, Полнота = {:.3f}, F1 = {:.3f}".format(
        res_tree[max_index_tree][0], res_tree[max_index_tree][1], res_tree[max_index_tree][2], res_tree[max_index_tree][3]))
# Out:
# Лучший результат:
# Порог = 0.58 | Точность = 0.569, Полнота = 0.636, F1 = 0.600

# %% [markdown]
# #### Модель случайного леса
#
# Возьмем ранее подобранный гиперпараметр `max_depth`=8 и `n_estimators`=16.

# %%
model_forest = RandomForestClassifier(random_state=12345, n_estimators=16, max_depth=8, class_weight='balanced') # модель
model_forest.fit(features_train, target_train) # обучение модель 
probabilities_valid_forest = model_forest.predict_proba(features_valid) 
probabilities_one_valid_forest = probabilities_valid_tree[:, 1]

res_forest = []
res_f1 = []

for threshold in np.arange(0, 1, 0.02):
    predicted_valid = probabilities_one_valid_forest > threshold 
    precision = precision_score(target_valid, predicted_valid)
    recall = recall_score(target_valid, predicted_valid)
    f1 = f1_score(target_valid, predicted_valid)
    res_forest.append([threshold, precision, recall, f1])
    res_f1.append(f1)

    #print("Порог = {:.2f} | Точность = {:.3f}, Полнота = {:.3f}, F1 = {:.3f}".format(
        #threshold, precision, recall, f1))

max_index_forest = res_f1.index(max(res_f1))
    
        
print('Лучший результат:')
print("Порог = {:.2f} | Точность = {:.3f}, Полнота = {:.3f}, F1 = {:.3f}".format(
        res_forest[max_index_forest][0], res_forest[max_index_forest][1], res_forest[max_index_forest][2], res_forest[max_index_forest][3]))
# Out:
# Лучший результат:
# Порог = 0.58 | Точность = 0.569, Полнота = 0.636, F1 = 0.600

# %% [markdown]
# #### Модель логистической регрессии

# %%
model_Log = LogisticRegression(random_state=12345, solver='lbfgs', max_iter=1000)
model_Log.fit(features_upsampled, target_upsampled)
prediction_valid_Log = model_Log.predict_proba(features_valid) 
probabilities_one_valid_log = prediction_valid_Log[:, 1]

res_log = []
res_f1 = []

for threshold in np.arange(0, 1, 0.02):
    predicted_valid = probabilities_one_valid_log > threshold 
    precision = precision_score(target_valid, predicted_valid)
    recall = recall_score(target_valid, predicted_valid)
    f1 = f1_score(target_valid, predicted_valid)
    res_log.append([threshold, precision, recall, f1])
    res_f1.append(f1)

    #print("Порог = {:.2f} | Точность = {:.3f}, Полнота = {:.3f}, F1 = {:.3f}".format(
        #threshold, precision, recall, f1))

max_index_log = res_f1.index(max(res_f1))
    
        
print('Лучший результат:')
print("Порог = {:.2f} | Точность = {:.3f}, Полнота = {:.3f}, F1 = {:.3f}".format(
        res_log[max_index_log][0], res_log[max_index_log][1], res_log[max_index_log][2], res_log[max_index_log][3]))
# Out:
# Лучший результат:
# Порог = 0.50 | Точность = 0.324, Полнота = 0.641, F1 = 0.430
# /opt/conda/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# #### Сравнение моделей
#
# Выведем полученные результаты в одну таблицу.

# %%
dict1 = {'precision': [res_tree[max_index_tree][1], res_forest[max_index_forest][1], res_log[max_index_log][1]], 'recall': [res_tree[max_index_tree][2], res_forest[max_index_forest][2], res_log[max_index_log][2]], 'f1': [res_tree[max_index_tree][3], res_forest[max_index_forest][3], res_log[max_index_log][3]]}

data_metrics_balanced_threshold = pd.DataFrame(data=dict1, index=['Решающее дерево', 'Случайный лес', 'Логистическая регрессия'])
data_metrics_balanced_threshold
# Out:
#                          precision    recall        f1
# Решающее дерево           0.568710  0.635934  0.600446
# Случайный лес             0.568710  0.635934  0.600446
# Логистическая регрессия   0.323775  0.640662  0.430159

# %% [markdown]
# Хороший результат показывают модели решающего дерева и случайного леса.

# %% [markdown]
# ### Вывод

# %% [markdown]
# Для выбора наилучшей стратегии обучения модели выведем все таблицы с метриками.

# %%
print(bold_text('До борьбы с дисбалансом:'))
display(data_metrics)
print()

print(bold_text('После борьбы с дисбалансом с помощью взвешивания классов:'))
display(data_metrics_balanced)
print()

print(bold_text('После борьбы с дисбалансом с помощью увеличения выборки:'))
display(data_metrics_balanced_increase)
print()

print(bold_text('После борьбы с дисбалансом с помощью уменьшения выборки:'))
display(data_metrics_balanced_decrease)
print()

print(bold_text('После борьбы с дисбалансом с помощью взвешивания классов и изменения порога классификации:'))
display(data_metrics_balanced_threshold)
# Out:
# До борьбы с дисбалансом:
#                                f1        time    recall  precision  accuracy
# Решающее дерево          0.535988    2.997033  0.413712   0.729167    0.8435
# Случайный лес            0.558209  167.395690  0.413712   0.729167    0.8435
# Логистическая регрессия  0.137374    0.446355  0.080378   0.472222    0.7865
# После борьбы с дисбалансом с помощью взвешивания классов:
#                                f1        time    recall  precision  accuracy
# Решающее дерево          0.580913    2.940592  0.387707   0.752294    0.8435
# Случайный лес            0.622460  166.053716  0.387707   0.752294    0.8435
# Логистическая регрессия  0.429477    0.282751  0.640662   0.323004    0.6400
# После борьбы с дисбалансом с помощью увеличения выборки:
#                                f1        time    recall  precision  accuracy
# Решающее дерево          0.580913    3.436712  0.510638   0.644776     0.837
# ...

# %% [markdown]
# Анализируя полученную таблицу, видно, что наилучшие результаты мы получаем при борьбе с дисбалансом с помощью увеличения выборки и взвешивания классов с и без изменением порога классификации.
#
# Принимаем решение использовать метод случайного леса с предварительной борьбой с дисбалансом с помощью увеличения выборки, так как данное сочетание методов приводит к наилучшим значениям метрик (и к одному из наибольших значений F1-меры).

# %% [markdown]
# ## Тестирование модели

# %% [markdown]
# Попробуем улучшить качество выбранной модели (случайный лес) путем объединения валидационной и тренировочной выборки в одну обучающую.

# %%
features_train_res = pd.concat([features_train, features_valid], ignore_index=True)
display('features_train_res', features_train_res.head())
print()
print(f'В таблице features_train было {features_train.shape[0]} строк.')
print(f'В таблице features_valid было {features_valid.shape[0]} строк.')
print()
print(f'В итоговой таблице features_train_res: {features_train_res.shape[0]} строк.')
print()
target_train_res = pd.concat([target_train, target_valid], ignore_index=True)
display('target_train_res', target_train_res.head())
print()
print(f'В таблице features_train было {target_train.shape[0]} строк.')
print(f'В таблице features_valid было {target_valid.shape[0]} строк.')
print()
print(f'В итоговой таблице target_train_res: {target_train_res.shape[0]} строк.')
# Out:
# 'features_train_res'
#    credit_score  age  tenure    balance  num_of_products  has_cr_card  \
# 0           567   35     8.0  153137.74                1            1
# 1           711   37     8.0  113899.92                1            0
# 2           850   44     3.0  140393.65                2            0
# 3           512   24     6.0       0.00                2            1
# 4           665   27     2.0  147435.96                1            0
#
#    is_active_member  estimated_salary  gender_Male  geography_Germany  \
# 0                 0          88659.07            1                  0
# 1                 0          80215.20            0                  0
# 2                 1         186285.52            1                  1
# 3                 0          37654.31            1                  0
# 4                 0         187508.06            0                  1
#
#    geography_Spain
# 0                1
# 1                0
# 2                0
# ...

# %% [markdown]
# Теперь обучим модель случайного леса с гиперпараметрами, выбранными ранее, на новой обучающей выборке и посчитаем значения различных метрик.

# %%
model = RandomForestClassifier(random_state=12345, n_estimators=37, max_depth=10) # модель
features_train_res_upsampled, target_train_res_upsampled = upsample(features_train_res, target_train_res, 4) # увеличение выборки
model.fit(features_train_res_upsampled, target_train_res_upsampled) # обучение модели 
predicted_res = model.predict(features_test)

precision = precision_score(target_test, predicted_res)
recall = recall_score(target_test, predicted_res)
f1_score = f1_score(target_test, predicted_res)

probabilities_test = model.predict_proba(features_test)
probabilities_one_test = probabilities_test[:, 1]

auc_roc = roc_auc_score(target_test, probabilities_one_test)

print('Значение precision =', precision, end='\n')
print('Значение recall =', recall, end='\n')
print('Значение f1_score =', f1_score, end='\n')
print('Значение auc_roc =', auc_roc)
# Out:
# Значение precision = 0.5502846299810247
# Значение recall = 0.69377990430622
# Значение f1_score = 0.6137566137566137
# Значение auc_roc = 0.8537010265002812

# %% [markdown]
# Получили значение F1-меры равное ~0.61.
#
# Теперь построим ROC-кривую.

# %%
fpr, tpr, thresholds = roc_curve(target_test, probabilities_one_test)

plt.figure()
plt.plot(fpr, tpr)  
plt.plot([0, 1], [0, 1], linestyle='--')
plt.ylim([0.0, 1.0])
plt.xlim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC-кривая')

plt.show()

# %% [markdown]
# Также проверим модель на адекватность.
#
# Для проверки модели на адекватность создадим базовую модель `base_model`, представляющую собой простейшую (dummy) модель, которая всегда предсказывает наиболее часто встречающийся класс. Так мы получим контрольные данные для сравнительной оценки построенной нами более сложной модели.

# %%
base_model = DummyClassifier(strategy="most_frequent", random_state=12345)
base_model.fit(features_train_res_upsampled, target_train_res_upsampled) # обучение модели 
predictions_base_model = base_model.predict(features_test) # предсказания модели 

f1_base_model = f1_score(target_test, predictions_base_model)
print('Значение f1_score для базовой модели =', f1_base_model)
# Out:
# Значение f1_score для базовой модели = 0.3457402812241522

# %% [markdown]
# Значение метрики для модели DummyClassifier ниже, чем для выбранной нами модели случайного леса. Таким образом, модель адекватна.

# %% [markdown]
# ## Вывод

# %% [markdown]
# Анализируя проделанную работу, можно сделать следующие выводы:
#
# 1. Предобработка данных:
#
# - присутствовали пропущенные значения в столбце Tenure. Удалось из заменить;
# - отсутствовали дубликаты;
# - построены графики и изучены корреляции в данных. Мультиколлениарность не обнаружена.
#
# Данные были разделены на признаки и целевой признак. Исxодные данные не сбалансированы, так как в целевом признаке значений про клиентов не покинувших банк больше (20 %), чем с ушедших (80 %).
#
# 2. Обучение моделей без учета дисбаланса.
#
# - данные были разделены на три выборки: обучающую, валидационную и тестовую, в соотношении 3:1:1.
# - были исследованы три модели:
#     - модель "решающее дерево": подобран гиперпараметр `max_depth`
#     - модель "случайный лес": подобраны гиперпараметры `max_depth` и `n_estimators`
#     - модель "логистическая регрессия".
#
# Наилучший результат показывали модели решающего дерева и случайного леса.
#
# 3. Обучение моделей с учетом борьбы с дисбалансом.
#
# Были исследованы те же три модели. Для борьбы с дисбалансом использовались следующие методы:
#
# - взвешивание классов;
# - увеличение выборки;
# - уменьшение выборки;
# - изменение порога классификации.
#
# Сравнив полученные результаты для всех моделей и метолов борьбы с дисбалансом, было принято решение использовать метод случайного леса с предварительной борьбой с дисбалансом путем увеличения выборки, так как данное сочетание методов приводит к наибольшему значению метрик.
#
# 4. Тестирование модели
#
# Было произведено тестирование выбранной модели, по итогу которго получено значение F1-меры равное ~0.61, что является хорошим результатом.
#
# Была проведена проверка модели на адекватность. Для сравнеиня значений метрики была взята модель `DummyClassifier`. Значение ее метрики оказалось ниже, чем для выбранной нами модели случайного леса. Таким образом, модель случайног леса прошла проверку на адекватность.

# %% [markdown]
# ## Чек-лист готовности проекта

# %% [markdown]
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [x]  Весь код выполняется без ошибок
# - [x]  Ячейки с кодом расположены в порядке исполнения
# - [x]  Выполнен шаг 1: данные подготовлены
# - [x]  Выполнен шаг 2: задача исследована
#     - [x]  Исследован баланс классов
#     - [x]  Изучены модели без учёта дисбаланса
#     - [x]  Написаны выводы по результатам исследования
# - [x]  Выполнен шаг 3: учтён дисбаланс
#     - [x]  Применено несколько способов борьбы с дисбалансом
#     - [x]  Написаны выводы по результатам исследования
# - [x]  Выполнен шаг 4: проведено тестирование
# - [x]  Удалось достичь *F1*-меры не менее 0.59
# - [x]  Исследована метрика *AUC-ROC*

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span></li><li><span><a href="#Исследование-задачи" data-toc-modified-id="Исследование-задачи-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Исследование задачи</a></span><ul class="toc-item"><li><span><a href="#Подготовка-данных-для-выборок" data-toc-modified-id="Подготовка-данных-для-выборок-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Подготовка данных для выборок</a></span></li><li><span><a href="#Проверка-на-баланс/дисбаланс-классов" data-toc-modified-id="Проверка-на-баланс/дисбаланс-классов-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Проверка на баланс/дисбаланс классов</a></span></li><li><span><a href="#Обучение-моделей-без-учета-дисбаланса" data-toc-modified-id="Обучение-моделей-без-учета-дисбаланса-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Обучение моделей без учета дисбаланса</a></span><ul class="toc-item"><li><span><a href="#Модель-решающего-дерева" data-toc-modified-id="Модель-решающего-дерева-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Модель решающего дерева</a></span></li><li><span><a href="#Модель-случайного-леса" data-toc-modified-id="Модель-случайного-леса-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Модель случайного леса</a></span></li><li><span><a href="#Модель-логистической-регрессии" data-toc-modified-id="Модель-логистической-регрессии-2.3.3"><span class="toc-item-num">2.3.3&nbsp;&nbsp;</span>Модель логистической регрессии</a></span></li><li><span><a href="#Сравнение-моделей" data-toc-modified-id="Сравнение-моделей-2.3.4"><span class="toc-item-num">2.3.4&nbsp;&nbsp;</span>Сравнение моделей</a></span></li></ul></li></ul></li><li><span><a href="#Борьба-с-дисбалансом" data-toc-modified-id="Борьба-с-дисбалансом-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Борьба с дисбалансом</a></span><ul class="toc-item"><li><span><a href="#Взвешивание-классов" data-toc-modified-id="Взвешивание-классов-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Взвешивание классов</a></span><ul class="toc-item"><li><span><a href="#Модель-решающего-дерева" data-toc-modified-id="Модель-решающего-дерева-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Модель решающего дерева</a></span></li><li><span><a href="#Модель-случайного-леса" data-toc-modified-id="Модель-случайного-леса-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>Модель случайного леса</a></span></li><li><span><a href="#Модель-логистической-регрессии" data-toc-modified-id="Модель-логистической-регрессии-3.1.3"><span class="toc-item-num">3.1.3&nbsp;&nbsp;</span>Модель логистической регрессии</a></span></li><li><span><a href="#Сравнение-моделей" data-toc-modified-id="Сравнение-моделей-3.1.4"><span class="toc-item-num">3.1.4&nbsp;&nbsp;</span>Сравнение моделей</a></span></li></ul></li><li><span><a href="#Увеличение-выборки" data-toc-modified-id="Увеличение-выборки-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Увеличение выборки</a></span><ul class="toc-item"><li><span><a href="#Модель-решающего-дерева" data-toc-modified-id="Модель-решающего-дерева-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Модель решающего дерева</a></span></li><li><span><a href="#Модель-случайного-леса" data-toc-modified-id="Модель-случайного-леса-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Модель случайного леса</a></span></li><li><span><a href="#Модель-логистической-регрессии" data-toc-modified-id="Модель-логистической-регрессии-3.2.3"><span class="toc-item-num">3.2.3&nbsp;&nbsp;</span>Модель логистической регрессии</a></span></li><li><span><a href="#Сравнение-моделей" data-toc-modified-id="Сравнение-моделей-3.2.4"><span class="toc-item-num">3.2.4&nbsp;&nbsp;</span>Сравнение моделей</a></span></li></ul></li><li><span><a href="#Уменьшение-выборки" data-toc-modified-id="Уменьшение-выборки-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Уменьшение выборки</a></span><ul class="toc-item"><li><span><a href="#Модель-решающего-дерева" data-toc-modified-id="Модель-решающего-дерева-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Модель решающего дерева</a></span></li><li><span><a href="#Модель-случайного-леса" data-toc-modified-id="Модель-случайного-леса-3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>Модель случайного леса</a></span></li><li><span><a href="#Модель-логистической-регрессии" data-toc-modified-id="Модель-логистической-регрессии-3.3.3"><span class="toc-item-num">3.3.3&nbsp;&nbsp;</span>Модель логистической регрессии</a></span></li><li><span><a href="#Сравнение-моделей" data-toc-modified-id="Сравнение-моделей-3.3.4"><span class="toc-item-num">3.3.4&nbsp;&nbsp;</span>Сравнение моделей</a></span></li></ul></li><li><span><a href="#Изменение-порога" data-toc-modified-id="Изменение-порога-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Изменение порога</a></span><ul class="toc-item"><li><span><a href="#Модель-решающего-дерева" data-toc-modified-id="Модель-решающего-дерева-3.4.1"><span class="toc-item-num">3.4.1&nbsp;&nbsp;</span>Модель решающего дерева</a></span></li><li><span><a href="#Модель-случайного-леса" data-toc-modified-id="Модель-случайного-леса-3.4.2"><span class="toc-item-num">3.4.2&nbsp;&nbsp;</span>Модель случайного леса</a></span></li><li><span><a href="#Модель-логистической-регрессии" data-toc-modified-id="Модель-логистической-регрессии-3.4.3"><span class="toc-item-num">3.4.3&nbsp;&nbsp;</span>Модель логистической регрессии</a></span></li><li><span><a href="#Сравнение-моделей" data-toc-modified-id="Сравнение-моделей-3.4.4"><span class="toc-item-num">3.4.4&nbsp;&nbsp;</span>Сравнение моделей</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Тестирование-модели" data-toc-modified-id="Тестирование-модели-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Тестирование модели</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>
